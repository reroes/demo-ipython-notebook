# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

print("Versión de Python:     ", sys.version)
print("Versión de Numpy:      ", np.version.short_version)
print("Versión de Matplotlib: ", matplotlib.__version__)
# Out:
# ('Versi\xc3\xb3n de Python:     ', '2.7.6 (default, Mar 22 2014, 22:59:56) \n[GCC 4.8.2]')
# ('Versi\xc3\xb3n de Numpy:      ', '1.9.2')
# ('Versi\xc3\xb3n de Matplotlib: ', '1.4.3')

# %%
ls
# Out:
# Base_Defunciones_Generales_año_2013.sav  Ejemplo2.ipynb
# datademo.csv                             Ejemplo-Matplotlib.ipynb
# defu2014.csv                             Ejemplo - Pandas DataFrame.ipynb
# defunciones.csv                          Ejemplo - Pandas Series.ipynb
# dummy.data                               Matrimonios_2014.csv
# EDG_2014.sav                             Matrimonios_2014.sav
# Ejemplo1-2014.ipynb                      Untitled-Copy5.ipynb
# Ejemplo1.ipynb

# %%
df = pd.read_csv("defu2014.csv")

# %%
df.keys()
# Out:
# Index([u'Unnamed: 0', u'ofi_insc', u'prov_insc', u'cant_insc', u'parr_insc', u'anio_insc', u'mes_insc', u'dia_insc', u'fecha_insc', u'nac_fall', u'cod_pais', u'sexo', u'anio_nac', u'mes_nac', u'dia_nac', u'fecha_nac', u'anio_fall', u'mes_fall', u'dia_fall', u'fecha_fall', u'cod_edad', u'edad', u'prov_res', u'cant_res', u'parr_res', u'area_res', u'est_civil', u'sabe_leer', u'niv_inst', u'etnia', u'lugar_ocur', u'prov_fall', u'cant_fall', u'parr_fall', u'area_fall', u'causa4', u'causa', u'mor_viol', u'lug_viol', u'mor_mat', u'mor_relac', u'autopsia', u'cer_por', u'parent_fall', u'lc1', u'causa103', u'causa80', u'causa67A', u'causa67B'], dtype='object')

# %%
df.causa103.value_counts(normalize=True)[:10].sort(inplace=False).plot('barh');

# %%
df[df.sexo.str.strip()=='Mujer'].causa103.value_counts(normalize=True)[:15].sort(inplace=False).plot('barh');

# %%
df[df.sexo.str.strip()=='Hombre'].causa103.value_counts(normalize=True)[:15].sort(inplace=False).plot('barh');

# %%
df.sexo.value_counts(normalize=True)[:15].sort(inplace=False).plot('area');

# %%
plt.scatter(df.edad, df.edad, s=df.area_fall)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-26637241848b> in <module>()
# ----> 1 plt.scatter(df.edad, df.edad, s=df.area_fall)
#
# /home/reroes/entornosvirtuales/envcientifico/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3198         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3199                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3200                          linewidths=linewidths, verts=verts, **kwargs)
#    3201         draw_if_interactive()
#    3202     finally:
#
# /home/reroes/entornosvirtuales/envcientifico/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
# ...

# %%
df.groupby('mes_insc').causa103.count().plot();

# %%
df.keys()
df.groupby('autopsia').causa103.count().plot();

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'folio', u'ofi_insc', u'prov_insc', u'cant_insc', u'parr_insc', u'anio_insc', u'mes_insc', u'dia_insc', u'fecha_insc', u'acta_insc', u'sexo', u'anio_nac', u'mes_nac', u'dia_nac', u'fecha_nac', u'anio_fall', u'mes_fall', u'dia_fall', u'fecha_fall', u'nac_fall', u'cod_pais', u'edad', u'cod_edad', u'prov_res', u'cant_res', u'parr_res', u'loc_res', u'area_res', u'est_civil', u'sabe_leer', u'niv_inst', u'etnia', u'lugar_ocur', u'cod_esta', u'prov_fall', u'cant_fall', u'parr_fall', u'loc_fall', u'area_fall', u'causa4', u'mor_mat', u'mor_viol', u'lug_viol', u'autopsia', u'cer_por', u'parent_fall', u'causa', u'causa103', u'causa80', u'causa67A', u'causa67B', u'lc1'], dtype='object')

# %%
pichincha = df.groupby('dia_fall').prov_insc.count()
guayas = df.groupby('dia_fall').prov_insc.count()
pichincha.plot(label='Pichincha')
guayas.plot(label='Guayas')
plt.legend(loc='best')

# %%
pichincha = df[df['prov_insc'].str.strip()=='Pichincha'].groupby('dia_fall').prov_insc.count()
guayas = df[df['prov_insc'].str.strip()=='Guayas'].groupby('dia_fall').prov_insc.count()
pichincha.plot(label='Pichincha')
guayas.plot(label='Guayas')
plt.legend(loc='best')

# %%
pichincha = df[df['prov_insc'].str.strip()=='Pichincha'].groupby('area_fall').prov_insc.count()
guayas = df[df['prov_insc'].str.strip()=='Loja'].groupby('area_fall').prov_insc.count()
pichincha.plot(label='Pichincha')
guayas.plot(label='Loja')
plt.legend(loc='best')

# %%
df.groupby('prov_insc').hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-37f59858c34f> in <module>()
# ----> 1 df.groupby('prov_insc').hist()
#
# /home/reroes/entornosvirtuales/envcientifico/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in hist(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#
# /home/reroes/entornosvirtuales/envcientifico/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in wrapper(*args, **kwargs)
#     554             # exception below
#     555             if name in _plotting_methods:
# --> 556                 return self.apply(curried)
#     557
#     558             try:
#
# /home/reroes/entornosvirtuales/envcientifico/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
# ...
